# %% [markdown]
# ###Project Title: "Feedback Analyzer"

# %%
## As the user to input A sentence Representing feedback
Cust_Feedback=input("Enter your feedback:")
Cust_Feedback

###Count how many words are in the sentence
print(len(Cust_Feedback.split()))
## Cheque how many times the word data appears in the sentence
print(Cust_Feedback.count("data"))
### Extract and print the first 5 Last five characters of the feedback separately
print(Cust_Feedback[:4])
print()
print(Cust_Feedback[-5:])
### Reverse the sentence and print it.
print(Cust_Feedback[::-1])
# Out:
# Enter your feedback: Very good data
# 3
# 1
#  Ver
#
#  data
# atad doog yreV
